# %% [markdown]
# ## Import Needed Modules

# %%
import json
import random
import numpy as np

import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
#
# [nltk_data]   Package punkt is already up-to-date!
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## Data Analysis and Preprcessing

# %% [markdown]
# #### Read data

# %%
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']

# %% [markdown]
# ### Preprocessing Text

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)

        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")
print (len(words), "unique lemmatized words")
print (len(classes), "classes", classes)
# Out:
# 161 documents
#
# 107 unique lemmatized words
#
# 51 classes ['Adventure stories', 'American fiction', 'Architecture', 'Art', 'Biography & Autobiography', 'Body, Mind & Spirit', 'Business & Economics', "Children's stories", 'Comics & Graphic Novels', 'Computers', 'Cooking', 'Detective and mystery stories', 'Drama', 'Education', 'English fiction', 'Family & Relationships', 'Fantasy fiction', 'Fiction', 'Foreign Language Study', 'Games', 'Health & Fitness', 'History', 'Humor', 'Juvenile Fiction', 'Juvenile Nonfiction', 'Language Arts & Disciplines', 'Law', 'Literary Collections', 'Literary Criticism', 'Medical', 'Music', 'Nature', 'Performing Arts', 'Philosophy', 'Photography', 'Poetry', 'Political Science', 'Psychology', 'Religion', 'Science', 'Science fiction', 'Self-Help', 'Social Science', 'Sports & Recreation', 'Travel', 'True Crime', 'Young Adult Fiction', 'book_search', 'goodbye', 'greeting', 'thanks']

# %% [markdown]
# ### Initializing Training Data

# %%
training = []
output_empty = [0] * len(classes)

for doc in documents:

    # initializing bag of words
    bag = []

    # list of tokenized words for the pattern
    pattern_words = doc[0]

    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]

    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training, dtype=object)

# create train and test lists. X - patterns, Y - intents
train_x = list(training[:, 0])
train_y = list(training[:, 1])
# Out:
# <ipython-input-5-554380a06ec6>:26: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#
#   training = np.array(training)

# %% [markdown]
# ## Model Training

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=500, batch_size=5, verbose=1)
model.save('model.h5', hist)
# Out:
# Epoch 1/500
#
# 33/33 [==============================] - 11s 5ms/step - loss: 3.9239 - accuracy: 0.0497
#
# Epoch 2/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 3.9209 - accuracy: 0.0062
#
# Epoch 3/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 3.8559 - accuracy: 0.0559
#
# Epoch 4/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 3.8440 - accuracy: 0.0621
#
# Epoch 5/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 3.7232 - accuracy: 0.0870
#
# Epoch 6/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 3.6481 - accuracy: 0.1366
#
# Epoch 7/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 3.5769 - accuracy: 0.1615
#
# Epoch 8/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 3.4426 - accuracy: 0.1801
#
# Epoch 9/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 3.2520 - accuracy: 0.2547
#
# Epoch 10/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 3.1524 - accuracy: 0.2298
#
# Epoch 11/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 2.9669 - accuracy: 0.2795
#
# Epoch 12/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 2.7641 - accuracy: 0.3354
#
# Epoch 13/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 2.7193 - accuracy: 0.3416
#
# Epoch 14/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 2.5217 - accuracy: 0.3602
#
# Epoch 15/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 2.1998 - accuracy: 0.4658
#
# Epoch 16/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 2.1118 - accuracy: 0.4472
#
# Epoch 17/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.9458 - accuracy: 0.4596
#
# Epoch 18/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.9909 - accuracy: 0.4783
#
# Epoch 19/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.8818 - accuracy: 0.5031
#
# Epoch 20/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.6715 - accuracy: 0.5466
#
# Epoch 21/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.5587 - accuracy: 0.5590
#
# Epoch 22/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.4826 - accuracy: 0.5901
#
# Epoch 23/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.4848 - accuracy: 0.5466
#
# Epoch 24/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.2369 - accuracy: 0.6894
#
# Epoch 25/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.3003 - accuracy: 0.6025
#
# Epoch 26/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.3293 - accuracy: 0.6335
#
# Epoch 27/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.1588 - accuracy: 0.6460
#
# Epoch 28/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.0310 - accuracy: 0.7019
#
# Epoch 29/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.1261 - accuracy: 0.6708
#
# Epoch 30/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.9498 - accuracy: 0.7143
#
# Epoch 31/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.1070 - accuracy: 0.7019
#
# Epoch 32/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 1.0139 - accuracy: 0.7143
#
# Epoch 33/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.9696 - accuracy: 0.7081
#
# Epoch 34/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.7925 - accuracy: 0.7702
#
# Epoch 35/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.7676 - accuracy: 0.7888
#
# Epoch 36/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.6981 - accuracy: 0.8075
#
# Epoch 37/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.7900 - accuracy: 0.7826
#
# Epoch 38/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.7719 - accuracy: 0.7578
#
# Epoch 39/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.7927 - accuracy: 0.7578
#
# Epoch 40/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.7484 - accuracy: 0.7950
#
# Epoch 41/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.8243 - accuracy: 0.7391
#
# Epoch 42/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.7285 - accuracy: 0.7888
#
# Epoch 43/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.7188 - accuracy: 0.7764
#
# Epoch 44/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5590 - accuracy: 0.8199
#
# Epoch 45/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.6705 - accuracy: 0.7888
#
# Epoch 46/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.6781 - accuracy: 0.8012
#
# Epoch 47/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5894 - accuracy: 0.7950
#
# Epoch 48/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5942 - accuracy: 0.8385
#
# Epoch 49/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5883 - accuracy: 0.8261
#
# Epoch 50/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5086 - accuracy: 0.8571
#
# Epoch 51/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.6366 - accuracy: 0.7888
#
# Epoch 52/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5311 - accuracy: 0.8199
#
# Epoch 53/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4873 - accuracy: 0.8634
#
# Epoch 54/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4655 - accuracy: 0.9068
#
# Epoch 55/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4048 - accuracy: 0.8944
#
# Epoch 56/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.6106 - accuracy: 0.8261
#
# Epoch 57/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5147 - accuracy: 0.8571
#
# Epoch 58/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5623 - accuracy: 0.8137
#
# Epoch 59/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4310 - accuracy: 0.9006
#
# Epoch 60/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4335 - accuracy: 0.8696
#
# Epoch 61/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4605 - accuracy: 0.8447
#
# Epoch 62/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4552 - accuracy: 0.8571
#
# Epoch 63/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4255 - accuracy: 0.8820
#
# Epoch 64/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5254 - accuracy: 0.8447
#
# Epoch 65/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5531 - accuracy: 0.8634
#
# Epoch 66/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4360 - accuracy: 0.8944
#
# Epoch 67/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2719 - accuracy: 0.9130
#
# Epoch 68/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4654 - accuracy: 0.8509
#
# Epoch 69/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4581 - accuracy: 0.8696
#
# Epoch 70/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4114 - accuracy: 0.8944
#
# Epoch 71/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3673 - accuracy: 0.8696
#
# Epoch 72/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4964 - accuracy: 0.8509
#
# Epoch 73/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3358 - accuracy: 0.9130
#
# Epoch 74/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4287 - accuracy: 0.8634
#
# Epoch 75/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4098 - accuracy: 0.8758
#
# Epoch 76/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2450 - accuracy: 0.9255
#
# Epoch 77/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4174 - accuracy: 0.8696
#
# Epoch 78/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3564 - accuracy: 0.9068
#
# Epoch 79/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3615 - accuracy: 0.8634
#
# Epoch 80/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3282 - accuracy: 0.9130
#
# Epoch 81/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3204 - accuracy: 0.8820
#
# Epoch 82/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2722 - accuracy: 0.8882
#
# Epoch 83/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3887 - accuracy: 0.8820
#
# Epoch 84/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3692 - accuracy: 0.8385
#
# Epoch 85/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3146 - accuracy: 0.9130
#
# Epoch 86/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3193 - accuracy: 0.8882
#
# Epoch 87/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3113 - accuracy: 0.9130
#
# Epoch 88/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.5379 - accuracy: 0.8199
#
# Epoch 89/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3998 - accuracy: 0.8696
#
# Epoch 90/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3800 - accuracy: 0.8882
#
# Epoch 91/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3759 - accuracy: 0.8820
#
# Epoch 92/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2817 - accuracy: 0.9317
#
# Epoch 93/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.4376 - accuracy: 0.8509
#
# Epoch 94/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3884 - accuracy: 0.8944
#
# Epoch 95/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3338 - accuracy: 0.9068
#
# Epoch 96/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3308 - accuracy: 0.9130
#
# Epoch 97/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3722 - accuracy: 0.8882
#
# Epoch 98/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3146 - accuracy: 0.8882
#
# Epoch 99/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.4773 - accuracy: 0.8634
#
# Epoch 100/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3325 - accuracy: 0.8820
#
# Epoch 101/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3477 - accuracy: 0.8758
#
# Epoch 102/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2066 - accuracy: 0.9379
#
# Epoch 103/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3066 - accuracy: 0.8882
#
# Epoch 104/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3412 - accuracy: 0.8696
#
# Epoch 105/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2719 - accuracy: 0.9317
#
# Epoch 106/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3078 - accuracy: 0.9068
#
# Epoch 107/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2168 - accuracy: 0.9255
#
# Epoch 108/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2706 - accuracy: 0.9130
#
# Epoch 109/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2860 - accuracy: 0.8882
#
# Epoch 110/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2547 - accuracy: 0.9379
#
# Epoch 111/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3307 - accuracy: 0.8944
#
# Epoch 112/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3513 - accuracy: 0.8696
#
# Epoch 113/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4173 - accuracy: 0.8758
#
# Epoch 114/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3698 - accuracy: 0.8696
#
# Epoch 115/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4422 - accuracy: 0.8634
#
# Epoch 116/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2686 - accuracy: 0.9068
#
# Epoch 117/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2360 - accuracy: 0.9193
#
# Epoch 118/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2580 - accuracy: 0.9193
#
# Epoch 119/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3425 - accuracy: 0.8882
#
# Epoch 120/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2257 - accuracy: 0.9255
#
# Epoch 121/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3641 - accuracy: 0.9068
#
# Epoch 122/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2384 - accuracy: 0.9193
#
# Epoch 123/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2275 - accuracy: 0.9379
#
# Epoch 124/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2477 - accuracy: 0.9379
#
# Epoch 125/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2207 - accuracy: 0.9317
#
# Epoch 126/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2345 - accuracy: 0.9317
#
# Epoch 127/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2259 - accuracy: 0.9193
#
# Epoch 128/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2271 - accuracy: 0.9441
#
# Epoch 129/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3406 - accuracy: 0.8944
#
# Epoch 130/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2835 - accuracy: 0.9068
#
# Epoch 131/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1596 - accuracy: 0.9441
#
# Epoch 132/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1922 - accuracy: 0.9193
#
# Epoch 133/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2655 - accuracy: 0.9130
#
# Epoch 134/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2756 - accuracy: 0.9441
#
# Epoch 135/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2258 - accuracy: 0.9130
#
# Epoch 136/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2516 - accuracy: 0.9379
#
# Epoch 137/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2407 - accuracy: 0.9193
#
# Epoch 138/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3284 - accuracy: 0.9068
#
# Epoch 139/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2391 - accuracy: 0.9130
#
# Epoch 140/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3254 - accuracy: 0.9006
#
# Epoch 141/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2544 - accuracy: 0.9255
#
# Epoch 142/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1592 - accuracy: 0.9627
#
# Epoch 143/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2416 - accuracy: 0.9317
#
# Epoch 144/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2043 - accuracy: 0.9193
#
# Epoch 145/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2162 - accuracy: 0.9255
#
# Epoch 146/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3769 - accuracy: 0.8696
#
# Epoch 147/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4057 - accuracy: 0.8509
#
# Epoch 148/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.6381 - accuracy: 0.8323
#
# Epoch 149/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2509 - accuracy: 0.9379
#
# Epoch 150/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3605 - accuracy: 0.8882
#
# Epoch 151/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2745 - accuracy: 0.9317
#
# Epoch 152/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2285 - accuracy: 0.9317
#
# Epoch 153/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1828 - accuracy: 0.9565
#
# Epoch 154/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1711 - accuracy: 0.9379
#
# Epoch 155/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2367 - accuracy: 0.9068
#
# Epoch 156/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2364 - accuracy: 0.9317
#
# Epoch 157/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2269 - accuracy: 0.9441
#
# Epoch 158/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2139 - accuracy: 0.9379
#
# Epoch 159/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2919 - accuracy: 0.9317
#
# Epoch 160/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3269 - accuracy: 0.9130
#
# Epoch 161/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3211 - accuracy: 0.8820
#
# Epoch 162/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4322 - accuracy: 0.8634
#
# Epoch 163/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4245 - accuracy: 0.8634
#
# Epoch 164/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4162 - accuracy: 0.8820
#
# Epoch 165/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3428 - accuracy: 0.9068
#
# Epoch 166/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4040 - accuracy: 0.8758
#
# Epoch 167/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3253 - accuracy: 0.8820
#
# Epoch 168/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2509 - accuracy: 0.9379
#
# Epoch 169/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2623 - accuracy: 0.9193
#
# Epoch 170/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2847 - accuracy: 0.9255
#
# Epoch 171/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2631 - accuracy: 0.9317
#
# Epoch 172/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3072 - accuracy: 0.9068
#
# Epoch 173/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3799 - accuracy: 0.8758
#
# Epoch 174/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3065 - accuracy: 0.8758
#
# Epoch 175/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2140 - accuracy: 0.9193
#
# Epoch 176/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1550 - accuracy: 0.9503
#
# Epoch 177/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2109 - accuracy: 0.9068
#
# Epoch 178/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1607 - accuracy: 0.9255
#
# Epoch 179/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2688 - accuracy: 0.9317
#
# Epoch 180/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2651 - accuracy: 0.9068
#
# Epoch 181/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3240 - accuracy: 0.9006
#
# Epoch 182/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1677 - accuracy: 0.9441
#
# Epoch 183/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2513 - accuracy: 0.9193
#
# Epoch 184/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1359 - accuracy: 0.9627
#
# Epoch 185/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1795 - accuracy: 0.9379
#
# Epoch 186/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2079 - accuracy: 0.9565
#
# Epoch 187/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1658 - accuracy: 0.9317
#
# Epoch 188/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2321 - accuracy: 0.9255
#
# Epoch 189/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3802 - accuracy: 0.8820
#
# Epoch 190/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2336 - accuracy: 0.9130
#
# Epoch 191/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1421 - accuracy: 0.9689
#
# Epoch 192/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2794 - accuracy: 0.8944
#
# Epoch 193/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1978 - accuracy: 0.9317
#
# Epoch 194/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2434 - accuracy: 0.9255
#
# Epoch 195/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2712 - accuracy: 0.9379
#
# Epoch 196/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2825 - accuracy: 0.9068
#
# Epoch 197/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1105 - accuracy: 0.9752
#
# Epoch 198/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2908 - accuracy: 0.9317
#
# Epoch 199/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3466 - accuracy: 0.8882
#
# Epoch 200/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2449 - accuracy: 0.9193
#
# Epoch 201/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3302 - accuracy: 0.8944
#
# Epoch 202/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3492 - accuracy: 0.8758
#
# Epoch 203/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2375 - accuracy: 0.9255
#
# Epoch 204/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2721 - accuracy: 0.9068
#
# Epoch 205/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2649 - accuracy: 0.9255
#
# Epoch 206/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2400 - accuracy: 0.9255
#
# Epoch 207/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2304 - accuracy: 0.9193
#
# Epoch 208/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1979 - accuracy: 0.9441
#
# Epoch 209/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2725 - accuracy: 0.9379
#
# Epoch 210/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2127 - accuracy: 0.9379
#
# Epoch 211/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1834 - accuracy: 0.9379
#
# Epoch 212/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2069 - accuracy: 0.9503
#
# Epoch 213/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3088 - accuracy: 0.9255
#
# Epoch 214/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2471 - accuracy: 0.9193
#
# Epoch 215/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1917 - accuracy: 0.9379
#
# Epoch 216/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3060 - accuracy: 0.9130
#
# Epoch 217/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2783 - accuracy: 0.9130
#
# Epoch 218/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1841 - accuracy: 0.9193
#
# Epoch 219/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2023 - accuracy: 0.9130
#
# Epoch 220/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2410 - accuracy: 0.9068
#
# Epoch 221/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3277 - accuracy: 0.9193
#
# Epoch 222/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1930 - accuracy: 0.9379
#
# Epoch 223/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2043 - accuracy: 0.9317
#
# Epoch 224/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1731 - accuracy: 0.9441
#
# Epoch 225/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2007 - accuracy: 0.9193
#
# Epoch 226/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1523 - accuracy: 0.9503
#
# Epoch 227/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1788 - accuracy: 0.9379
#
# Epoch 228/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3176 - accuracy: 0.9068
#
# Epoch 229/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2341 - accuracy: 0.9193
#
# Epoch 230/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3232 - accuracy: 0.9130
#
# Epoch 231/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2038 - accuracy: 0.9317
#
# Epoch 232/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2376 - accuracy: 0.9379
#
# Epoch 233/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3497 - accuracy: 0.9068
#
# Epoch 234/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2120 - accuracy: 0.9441
#
# Epoch 235/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1183 - accuracy: 0.9627
#
# Epoch 236/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1363 - accuracy: 0.9379
#
# Epoch 237/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2227 - accuracy: 0.9255
#
# Epoch 238/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2136 - accuracy: 0.9255
#
# Epoch 239/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1633 - accuracy: 0.9689
#
# Epoch 240/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9627
#
# Epoch 241/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2757 - accuracy: 0.9255
#
# Epoch 242/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2415 - accuracy: 0.9193
#
# Epoch 243/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2256 - accuracy: 0.9317
#
# Epoch 244/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1857 - accuracy: 0.9379
#
# Epoch 245/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2376 - accuracy: 0.9255
#
# Epoch 246/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1931 - accuracy: 0.9441
#
# Epoch 247/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2868 - accuracy: 0.9193
#
# Epoch 248/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2264 - accuracy: 0.9317
#
# Epoch 249/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2095 - accuracy: 0.9255
#
# Epoch 250/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1869 - accuracy: 0.9255
#
# Epoch 251/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2480 - accuracy: 0.9317
#
# Epoch 252/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1202 - accuracy: 0.9503
#
# Epoch 253/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3087 - accuracy: 0.9068
#
# Epoch 254/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1938 - accuracy: 0.9503
#
# Epoch 255/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2048 - accuracy: 0.9130
#
# Epoch 256/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3137 - accuracy: 0.9193
#
# Epoch 257/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1851 - accuracy: 0.9379
#
# Epoch 258/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3568 - accuracy: 0.9006
#
# Epoch 259/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2653 - accuracy: 0.9006
#
# Epoch 260/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2571 - accuracy: 0.9130
#
# Epoch 261/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2271 - accuracy: 0.9255
#
# Epoch 262/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2345 - accuracy: 0.9255
#
# Epoch 263/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1458 - accuracy: 0.9627
#
# Epoch 264/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1446 - accuracy: 0.9565
#
# Epoch 265/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1737 - accuracy: 0.9503
#
# Epoch 266/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1438 - accuracy: 0.9627
#
# Epoch 267/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1926 - accuracy: 0.9503
#
# Epoch 268/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2482 - accuracy: 0.9317
#
# Epoch 269/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1963 - accuracy: 0.9379
#
# Epoch 270/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3601 - accuracy: 0.9006
#
# Epoch 271/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1399 - accuracy: 0.9565
#
# Epoch 272/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2914 - accuracy: 0.9193
#
# Epoch 273/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2305 - accuracy: 0.9255
#
# Epoch 274/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3518 - accuracy: 0.9068
#
# Epoch 275/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2025 - accuracy: 0.9379
#
# Epoch 276/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2364 - accuracy: 0.9130
#
# Epoch 277/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2213 - accuracy: 0.9130
#
# Epoch 278/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1674 - accuracy: 0.9317
#
# Epoch 279/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2258 - accuracy: 0.9130
#
# Epoch 280/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2541 - accuracy: 0.9317
#
# Epoch 281/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3094 - accuracy: 0.9193
#
# Epoch 282/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1851 - accuracy: 0.9317
#
# Epoch 283/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1862 - accuracy: 0.9441
#
# Epoch 284/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2023 - accuracy: 0.9441
#
# Epoch 285/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1397 - accuracy: 0.9689
#
# Epoch 286/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2335 - accuracy: 0.9193
#
# Epoch 287/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1838 - accuracy: 0.9193
#
# Epoch 288/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2486 - accuracy: 0.9193
#
# Epoch 289/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3093 - accuracy: 0.9006
#
# Epoch 290/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2507 - accuracy: 0.9006
#
# Epoch 291/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2201 - accuracy: 0.9317
#
# Epoch 292/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2817 - accuracy: 0.9068
#
# Epoch 293/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2710 - accuracy: 0.9130
#
# Epoch 294/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2698 - accuracy: 0.8944
#
# Epoch 295/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2597 - accuracy: 0.8882
#
# Epoch 296/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3795 - accuracy: 0.8944
#
# Epoch 297/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2946 - accuracy: 0.8944
#
# Epoch 298/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1637 - accuracy: 0.9441
#
# Epoch 299/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1030 - accuracy: 0.9503
#
# Epoch 300/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1093 - accuracy: 0.9503
#
# Epoch 301/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1614 - accuracy: 0.9627
#
# Epoch 302/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1583 - accuracy: 0.9627
#
# Epoch 303/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2238 - accuracy: 0.9130
#
# Epoch 304/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1755 - accuracy: 0.9565
#
# Epoch 305/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1938 - accuracy: 0.9379
#
# Epoch 306/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1330 - accuracy: 0.9565
#
# Epoch 307/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1574 - accuracy: 0.9565
#
# Epoch 308/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2404 - accuracy: 0.9379
#
# Epoch 309/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2061 - accuracy: 0.9441
#
# Epoch 310/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2338 - accuracy: 0.9441
#
# Epoch 311/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1639 - accuracy: 0.9565
#
# Epoch 312/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1489 - accuracy: 0.9565
#
# Epoch 313/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1991 - accuracy: 0.9441
#
# Epoch 314/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3417 - accuracy: 0.9006
#
# Epoch 315/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3094 - accuracy: 0.9068
#
# Epoch 316/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2437 - accuracy: 0.9006
#
# Epoch 317/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1343 - accuracy: 0.9379
#
# Epoch 318/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2221 - accuracy: 0.9689
#
# Epoch 319/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1701 - accuracy: 0.9689
#
# Epoch 320/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1388 - accuracy: 0.9565
#
# Epoch 321/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2191 - accuracy: 0.9130
#
# Epoch 322/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1653 - accuracy: 0.9627
#
# Epoch 323/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2508 - accuracy: 0.9068
#
# Epoch 324/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2639 - accuracy: 0.9317
#
# Epoch 325/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1638 - accuracy: 0.9379
#
# Epoch 326/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2373 - accuracy: 0.9006
#
# Epoch 327/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1124 - accuracy: 0.9503
#
# Epoch 328/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3040 - accuracy: 0.9130
#
# Epoch 329/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2630 - accuracy: 0.9193
#
# Epoch 330/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1501 - accuracy: 0.9627
#
# Epoch 331/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1042 - accuracy: 0.9565
#
# Epoch 332/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2318 - accuracy: 0.9255
#
# Epoch 333/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2059 - accuracy: 0.9193
#
# Epoch 334/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2431 - accuracy: 0.9317
#
# Epoch 335/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2016 - accuracy: 0.9379
#
# Epoch 336/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2047 - accuracy: 0.9379
#
# Epoch 337/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9441
#
# Epoch 338/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2424 - accuracy: 0.9317
#
# Epoch 339/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2514 - accuracy: 0.9130
#
# Epoch 340/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2732 - accuracy: 0.9130
#
# Epoch 341/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1624 - accuracy: 0.9441
#
# Epoch 342/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2032 - accuracy: 0.9193
#
# Epoch 343/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1777 - accuracy: 0.9379
#
# Epoch 344/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2080 - accuracy: 0.9441
#
# Epoch 345/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1184 - accuracy: 0.9814
#
# Epoch 346/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2750 - accuracy: 0.9130
#
# Epoch 347/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1648 - accuracy: 0.9565
#
# Epoch 348/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1859 - accuracy: 0.9503
#
# Epoch 349/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3245 - accuracy: 0.8820
#
# Epoch 350/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1940 - accuracy: 0.9503
#
# Epoch 351/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2865 - accuracy: 0.9193
#
# Epoch 352/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2077 - accuracy: 0.9441
#
# Epoch 353/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2272 - accuracy: 0.9255
#
# Epoch 354/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1954 - accuracy: 0.9441
#
# Epoch 355/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1506 - accuracy: 0.9441
#
# Epoch 356/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1500 - accuracy: 0.9503
#
# Epoch 357/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1558 - accuracy: 0.9565
#
# Epoch 358/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1961 - accuracy: 0.9255
#
# Epoch 359/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0870 - accuracy: 0.9814
#
# Epoch 360/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2268 - accuracy: 0.9379
#
# Epoch 361/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2241 - accuracy: 0.9193
#
# Epoch 362/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2381 - accuracy: 0.9317
#
# Epoch 363/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0976 - accuracy: 0.9689
#
# Epoch 364/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2311 - accuracy: 0.9565
#
# Epoch 365/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2851 - accuracy: 0.9255
#
# Epoch 366/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2048 - accuracy: 0.9503
#
# Epoch 367/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2957 - accuracy: 0.9317
#
# Epoch 368/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1503 - accuracy: 0.9752
#
# Epoch 369/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2254 - accuracy: 0.9379
#
# Epoch 370/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2057 - accuracy: 0.9379
#
# Epoch 371/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0940 - accuracy: 0.9814
#
# Epoch 372/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0934 - accuracy: 0.9689
#
# Epoch 373/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1928 - accuracy: 0.9255
#
# Epoch 374/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2081 - accuracy: 0.9379
#
# Epoch 375/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2108 - accuracy: 0.9317
#
# Epoch 376/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2132 - accuracy: 0.9317
#
# Epoch 377/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1969 - accuracy: 0.9441
#
# Epoch 378/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1882 - accuracy: 0.9441
#
# Epoch 379/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2748 - accuracy: 0.9068
#
# Epoch 380/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0947 - accuracy: 0.9627
#
# Epoch 381/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2328 - accuracy: 0.9317
#
# Epoch 382/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1779 - accuracy: 0.9441
#
# Epoch 383/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1999 - accuracy: 0.9441
#
# Epoch 384/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3336 - accuracy: 0.8882
#
# Epoch 385/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.4324 - accuracy: 0.8571
#
# Epoch 386/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3027 - accuracy: 0.9006
#
# Epoch 387/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3224 - accuracy: 0.9006
#
# Epoch 388/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3364 - accuracy: 0.9006
#
# Epoch 389/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2145 - accuracy: 0.9068
#
# Epoch 390/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1429 - accuracy: 0.9627
#
# Epoch 391/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1688 - accuracy: 0.9565
#
# Epoch 392/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2742 - accuracy: 0.9255
#
# Epoch 393/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1473 - accuracy: 0.9503
#
# Epoch 394/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3217 - accuracy: 0.8882
#
# Epoch 395/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3729 - accuracy: 0.8571
#
# Epoch 396/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2529 - accuracy: 0.9317
#
# Epoch 397/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3401 - accuracy: 0.9130
#
# Epoch 398/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2320 - accuracy: 0.9503
#
# Epoch 399/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3061 - accuracy: 0.9068
#
# Epoch 400/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3395 - accuracy: 0.9130
#
# Epoch 401/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2826 - accuracy: 0.9068
#
# Epoch 402/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2283 - accuracy: 0.9379
#
# Epoch 403/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2225 - accuracy: 0.9441
#
# Epoch 404/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2113 - accuracy: 0.9379
#
# Epoch 405/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1732 - accuracy: 0.9565
#
# Epoch 406/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1689 - accuracy: 0.9565
#
# Epoch 407/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2988 - accuracy: 0.9006
#
# Epoch 408/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2431 - accuracy: 0.9379
#
# Epoch 409/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1840 - accuracy: 0.9317
#
# Epoch 410/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2126 - accuracy: 0.9193
#
# Epoch 411/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2469 - accuracy: 0.9068
#
# Epoch 412/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2584 - accuracy: 0.9255
#
# Epoch 413/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3994 - accuracy: 0.9068
#
# Epoch 414/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1792 - accuracy: 0.9255
#
# Epoch 415/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1612 - accuracy: 0.9752
#
# Epoch 416/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2297 - accuracy: 0.9379
#
# Epoch 417/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2622 - accuracy: 0.9317
#
# Epoch 418/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1273 - accuracy: 0.9689
#
# Epoch 419/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1950 - accuracy: 0.9503
#
# Epoch 420/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2790 - accuracy: 0.9255
#
# Epoch 421/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2552 - accuracy: 0.9130
#
# Epoch 422/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1501 - accuracy: 0.9441
#
# Epoch 423/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1332 - accuracy: 0.9565
#
# Epoch 424/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2197 - accuracy: 0.9255
#
# Epoch 425/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2834 - accuracy: 0.9317
#
# Epoch 426/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2331 - accuracy: 0.9193
#
# Epoch 427/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2336 - accuracy: 0.9317
#
# Epoch 428/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1555 - accuracy: 0.9565
#
# Epoch 429/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2325 - accuracy: 0.9193
#
# Epoch 430/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2203 - accuracy: 0.9255
#
# Epoch 431/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2662 - accuracy: 0.9379
#
# Epoch 432/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1879 - accuracy: 0.9503
#
# Epoch 433/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1099 - accuracy: 0.9565
#
# Epoch 434/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1460 - accuracy: 0.9441
#
# Epoch 435/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1905 - accuracy: 0.9255
#
# Epoch 436/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9379
#
# Epoch 437/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2490 - accuracy: 0.9130
#
# Epoch 438/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2180 - accuracy: 0.9193
#
# Epoch 439/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2901 - accuracy: 0.8944
#
# Epoch 440/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2695 - accuracy: 0.9068
#
# Epoch 441/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3216 - accuracy: 0.9193
#
# Epoch 442/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2565 - accuracy: 0.9255
#
# Epoch 443/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2842 - accuracy: 0.9193
#
# Epoch 444/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1922 - accuracy: 0.9441
#
# Epoch 445/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0953 - accuracy: 0.9876
#
# Epoch 446/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2265 - accuracy: 0.9441
#
# Epoch 447/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2055 - accuracy: 0.9441
#
# Epoch 448/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1797 - accuracy: 0.9503
#
# Epoch 449/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2610 - accuracy: 0.9379
#
# Epoch 450/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2333 - accuracy: 0.9130
#
# Epoch 451/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2024 - accuracy: 0.9441
#
# Epoch 452/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3383 - accuracy: 0.9068
#
# Epoch 453/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3322 - accuracy: 0.9130
#
# Epoch 454/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4345 - accuracy: 0.8696
#
# Epoch 455/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2873 - accuracy: 0.9130
#
# Epoch 456/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3775 - accuracy: 0.8634
#
# Epoch 457/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2975 - accuracy: 0.9193
#
# Epoch 458/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3598 - accuracy: 0.8696
#
# Epoch 459/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3035 - accuracy: 0.9317
#
# Epoch 460/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3114 - accuracy: 0.9006
#
# Epoch 461/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1863 - accuracy: 0.9441
#
# Epoch 462/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2010 - accuracy: 0.9441
#
# Epoch 463/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1981 - accuracy: 0.9441
#
# Epoch 464/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2306 - accuracy: 0.9379
#
# Epoch 465/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1572 - accuracy: 0.9503
#
# Epoch 466/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1742 - accuracy: 0.9503
#
# Epoch 467/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1118 - accuracy: 0.9689
#
# Epoch 468/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2213 - accuracy: 0.9379
#
# Epoch 469/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2866 - accuracy: 0.9317
#
# Epoch 470/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1868 - accuracy: 0.9441
#
# Epoch 471/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2386 - accuracy: 0.9130
#
# Epoch 472/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9255
#
# Epoch 473/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2805 - accuracy: 0.9193
#
# Epoch 474/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2385 - accuracy: 0.9006
#
# Epoch 475/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2973 - accuracy: 0.8882
#
# Epoch 476/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1711 - accuracy: 0.9317
#
# Epoch 477/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3357 - accuracy: 0.9255
#
# Epoch 478/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2402 - accuracy: 0.9317
#
# Epoch 479/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2260 - accuracy: 0.9379
#
# Epoch 480/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1243 - accuracy: 0.9565
#
# Epoch 481/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2497 - accuracy: 0.9193
#
# Epoch 482/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3332 - accuracy: 0.9317
#
# Epoch 483/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2225 - accuracy: 0.9193
#
# Epoch 484/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2346 - accuracy: 0.9130
#
# Epoch 485/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3177 - accuracy: 0.9130
#
# Epoch 486/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2172 - accuracy: 0.9441
#
# Epoch 487/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1521 - accuracy: 0.9441
#
# Epoch 488/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3360 - accuracy: 0.9317
#
# Epoch 489/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2367 - accuracy: 0.9441
#
# Epoch 490/500
#
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2481 - accuracy: 0.9193
#
# Epoch 491/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2191 - accuracy: 0.9379
#
# Epoch 492/500
#
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2206 - accuracy: 0.9193
#
# Epoch 493/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1627 - accuracy: 0.9503
#
# Epoch 494/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3817 - accuracy: 0.9255
#
# Epoch 495/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2298 - accuracy: 0.9068
#
# Epoch 496/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0833 - accuracy: 0.9689
#
# Epoch 497/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2062 - accuracy: 0.9379
#
# Epoch 498/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2726 - accuracy: 0.9317
#
# Epoch 499/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2228 - accuracy: 0.9317
#
# Epoch 500/500
#
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1148 - accuracy: 0.9565
#
# model created
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#
#   saving_api.save_model(

# %% [markdown]
# ## Chatbot Prediction

# %% [markdown]
# ### Function to clean user input

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]

    return sentence_words

# %% [markdown]
# ### Function for Bag of Wrds

# %%
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)

    # bag of words - matrix of N words, vocabulary matrix
    bag = [0] * len(words)
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s:

                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)

    return(np.array(bag))

# %% [markdown]
# ### Function for Class Prediction

# %%
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %% [markdown]
# ### Function to get chatbot response

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            response = random.choice(i['responses'])
            other_books = i.get('other_books', [])
            return response, other_books

# %% [markdown]
# ### Chatbot Function

# %%
def chatbot_response(msg):
    ints = predict_class(msg, model)
    res, other_books = getResponse(ints, intents)
    return res, other_books

# %%
def format_response(response):
    if response:
        if isinstance(response, str):
            formatted_response = ""
            for line in response.split(':'):
                formatted_response += f"{line.strip()}: \n"
            return formatted_response.strip()
        elif isinstance(response, dict):
            formatted_response = ""
            for key, value in response.items():
                formatted_response += f"{key}: {value}\n"
            return formatted_response
    else:
        return "I'm sorry, I didn't understand that."

# %% [markdown]
# ## Chatbot

# %%
chatbot_response('Recommend a book in History')
# Out:
# 1/1 [==============================] - 0s 65ms/step
# {'Book': 'The Chaneysville Incident',
#  'Feedback': "The legends say something happened in Chaneysville. The Chaneysville Incident is the powerful story of one man's obsession with discovering what that something was--a quest that takes the brilliant and bitter young black historian John Washington back through the secrets and buried evil of his heritage. Returning home to care for and then bury his father's closest friend and his own guardian, Old Jack Crawley, he comes upon the scant records of his family's proud and tragic history, which he drives himself to reconstruct and accept. This is the story of John's relationship with his family, the town, and the woman he loves; and also between the past and the present, between oppression and guilt, hate and violence, love and acceptance.",
#  'Rate': 3.96}
